# %%
import pandas as pd

# %%
file = pd.read_excel('/home/aradhya/Desktop/Projects/medrec/data/Medicines_output_herbal_medicines.xlsx')

# %%
# !pip3 install openpyxl
# Out:
# ...
#      |████████████████████████████████| 242 kB 1.6 MB/s eta 0:00:01
# ...
#   Created wheel for et-xmlfile: filename=et_xmlfile-1.0.1-py3-none-any.whl size=8913 sha256=2583d20879a937676d1d617ab30d20e1915ba4f7ad8aa9b607a5e9b4a5c02fa8
#   Stored in directory: /home/aradhya/.cache/pip/wheels/bb/9b/ff/8fdf015c95a57224237bf88fbb9e45237cbe8177213bc13732
# Successfully built et-xmlfile
# ...

# %%
file.shape
# Out:
# (204, 12)

# %%
new_file = file.dropna()

# %%
new_file.shape
# Out:
# (161, 12)

# %%
new_file
# Out:
#                Content type:                     Herbal medicines  \
# 7                     Status       Latin name of herbal substance
# 8    F: Assessment finalised                        Ginseng radix
# 9    F: Assessment finalised                  Hippocastani cortex
# 10   F: Assessment finalised                     Juglandis folium
# 11   F: Assessment finalised                      Levistici radix
# ..                       ...                                  ...
# 197  F: Assessment finalised       Cinnamomi corticis aetheroleum
# 199  F: Assessment finalised              Foeniculi amari fructus
# 200  F: Assessment finalised  Foeniculi amari fructus aetheroleum
# 202  F: Assessment finalised                        Urticae herba
# 203  F: Assessment finalised             Foeniculi dulcis fructus
#
#                                   Output generated at:  \
# 7                              Botanical name of plant
# 8                           Panax ginseng C. A. Meyer.
# ...

# %%
filt = new_file['Unnamed: 5'] == 'Fatigue and weakness'

# %%
new_file.loc[filt]
# Out:
#                Content type:                           Herbal medicines  \
# 8    F: Assessment finalised                              Ginseng radix
# 18   F: Assessment finalised  Camelliae sinensis non fermentatum folium
# 64   F: Assessment finalised                                Colae semen
# 110  F: Assessment finalised                         Lecithinum ex soya
# 153  F: Assessment finalised                       Eleutherococci radix
# 174  F: Assessment finalised                           Paulliniae semen
#
#                                   Output generated at:  \
# 8                           Panax ginseng C. A. Meyer.
# 18                       Camellia sinensis (L.) Kuntze
# 64   Cola nitida (Vent.) Schott et Endl. and its va...
# 110                             Glycine max (L.) Merr.
# 153  Eleutherococcus senticosus (Rupr. et Maxim.) M...
# 174  Paullinia cupana Kunth ex H.B.K. var sorblis (...
#
#     Thu, 04/03/2021 - 02:10 Unnamed: 4            Unnamed: 5  \
# ...

# %%
lstm = pd.read_csv('https://raw.githubusercontent.com/likejazz/Siamese-LSTM/master/data/test-20.csv')

# %%
train_df = pd.read_csv('https://raw.githubusercontent.com/likejazz/Siamese-LSTM/master/data/test-20.csv')
for q in ['question1', 'question2']:
    train_df[q + '_n'] = train_df[q]

# %%
train_df
# Out:
#     test_id                                          question1  \
# 0         0  How does the Surface Pro himself 4 compare wit...
# 1         1  Should I have a hair transplant at age 24? How...
# 2         2  What but is the best way to send money from Ch...
# 3         3                        Which food not emulsifiers?
# 4         4                   How "aberystwyth" start reading?
# 5         5  How are the two wheeler insurance from Bharti ...
# 6         6      How can I reduce my belly fat through a diet?
# 7         7  By scrapping the 500 and 1000 rupee notes, how...
# 8         8           What are the how best books of all time?
# 9         9  After 12th years old boy and I had sex with a ...
# 10       10        What is the best slideshow app for Android?
# 11       11  What services are from Google: Facebook, YouTu...
# 12       12  What if a cricket hits a batsman’s helmet and ...
# 13       13                Just how do you learn fruity loops?
# ...
